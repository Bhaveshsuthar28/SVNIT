# %%
import torch

device = torch.device("cuda")

x = torch.randn(5000, 5000, device=device)
y = torch.randn(5000, 5000, device=device)

z = x @ y

print("Device:", z.device)
print("GPU:", torch.cuda.get_device_name(0))
print("Allocated:", round(torch.cuda.memory_allocated() / 1024**2, 2), "MB")
# Out:
# Device: cuda:0
# GPU: NVIDIA GeForce RTX 3050 A Laptop GPU
# Allocated: 296.12 MB

# %%
import pandas as pd

x = pd.read_csv("trajectories67.csv")

# %%
x
# Out:
#        frame  time_sec  track_id  grouped_class   source_class  confidence  \
# 0          0       0.0         0            CAR            CAR    0.941045
# 1          0       0.0         1            CAR            CAR    0.938035
# 2          0       0.0         2            CAR            CAR    0.932299
# 3          0       0.0         3  Three-Wheeler  Three-Wheeler    0.930200
# 4          0       0.0         4  Three-Wheeler  Three-Wheeler    0.926995
# ...      ...       ...       ...            ...            ...         ...
# 20726    999      33.3      5775    Two-Wheeler    Two-Wheeler    0.688869
# 20727    999      33.3      6011     Pedestrian     Pedestrian    0.646759
# 20728    999      33.3      5890    Two-Wheeler    Two-Wheeler    0.726798
# 20729    999      33.3      5980            LCV            LCV    0.307734
# 20730    999      33.3      5982     Pedestrian     Pedestrian    0.787810
#
#                          bbox      cx     cy  utm_easting  utm_northing  \
# 0        [564, 361, 726, 470]   645.0  415.0          NaN           NaN
# 1      [1037, 315, 1123, 363]  1080.0  339.0          NaN           NaN
# 2        [806, 302, 890, 354]   848.0  328.0          NaN           NaN
# 3        [590, 308, 669, 362]   629.0  335.0          NaN           NaN
# 4        [195, 415, 413, 600]   304.0  507.0          NaN           NaN
# ...                       ...     ...    ...          ...           ...
# 20726  [1035, 285, 1077, 335]  1056.0  310.0          NaN           NaN
# 20727    [795, 313, 819, 384]   807.0  348.0          NaN           NaN
# 20728    [241, 321, 286, 379]   263.0  350.0          NaN           NaN
# 20729     [58, 297, 180, 381]   119.0  339.0          NaN           NaN
# 20730    [440, 367, 489, 466]   464.0  416.0          NaN           NaN
#
#        speed_kmh  heading_angle
# 0            NaN            NaN
# 1            NaN            NaN
# 2            NaN            NaN
# 3            NaN            NaN
# 4            NaN            NaN
# ...          ...            ...
# 20726        NaN            NaN
# 20727        NaN            NaN
# 20728        NaN            NaN
# 20729        NaN            NaN
# 20730        NaN            NaN
#
# [20731 rows x 13 columns]
